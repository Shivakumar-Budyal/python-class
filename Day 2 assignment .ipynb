# %%
# Hi letsupgarde , first of all i would like to say Thank you for Free classes
#I am new to the coding,  I am leraning from the scratch... literally  basic if you find mistakes
# let me know and correct me please

# %%
print("Shivakumar Budyal")
# Out:
# Shivakumar Budyal

# %%
#list Fuctions

# %%
lst=["Banglore","143","93.5"]

# %%
print(lst)
# Out:
# ['Banglore', '143', '93.5']

# %%
#append fuction

# %%
lst.append("Hyderabad")

# %%
print(lst)
# Out:
# ['Banglore', '143', '93.5', 'Hyderabad']

# %%
#insert fun

# %%
lst.insert(0,"Chennai")

# %%
print(lst)
# Out:
# ['Chennai', 'Banglore', '143', '93.5', 'Hyderabad']

# %%
#remove fun

# %%
lst.remove("143")

# %%
print(lst)
# Out:
# ['Chennai', 'Banglore', '93.5', 'Hyderabad']

# %%
#pop fun without index

# %%
lst.pop()
# Out:
# 'Hyderabad'

# %%
print(lst)
# Out:
# ['Chennai', 'Banglore', '93.5']

# %%
 lst=["Chennai","Banglore","143","Chennai"]

# %%
print(lst)
# Out:
# ['Chennai', 'Banglore', '143', 'Chennai']

# %%
#count fun

# %%
print(lst.count("Chennai"))
# Out:
# 2

# %%
#index fun

# %%
print(lst.index("143"))
# Out:
# 2

# %%
# dictoanaries and its fun

# %%
dit = {"name": "Shivakumar","USN": "20053571","College": "NHCE"}

# %%
dit
# Out:
# {'College': 'NHCE', 'USN': '20053571', 'name': 'Shivakumar'}

# %%
#retrive a value

# %%
dit.get("USN")
# Out:
# '20053571'

# %%
#add item

# %%
dit["location"]: "banglore"

# %%
dit
# Out:
# {'College': 'NHCE', 'USN': '20053571', 'name': 'Shivakumar'}

# %%
#dictionary funtions

# %%
dit={"1":"2","3":"4"}

# %%
dit
# Out:
# {'1': '2', '3': '4'}

# %%
#add item to dict

# %%
dit["5"]="6"

# %%
dit
# Out:
# {'1': '2', '3': '4', '5': '6'}

# %%
# retrive value from dict

# %%
dit.get("3")
# Out:
# '4'

# %%
#Update a particular item of dict

# %%
dit={"1":"2","3":"4"}

# %%
dit
# Out:
# {'1': '2', '3': '4'}

# %%
dit["1"]="10"

# %%
print(dit)
# Out:
# {'1': '10', '3': '4'}

# %%
#delete an item from dict

# %%
del dit["3"]

# %%
print(dit)
# Out:
# {'1': '10'}

# %%
# removing an orbitary item

# %%
dit={"1":"2","3":"4","x":"y"}

# %%
print(dit.popitem())
# Out:
# ('x', 'y')

# %%
print(dit)
# Out:
# {'1': '2', '3': '4'}

# %% [markdown]
# # Set and its different section

# %%
st = {10, 20, 20, 30, 40, "Shivakumar", 92.7}

# %%
print(st)
# Out:
# {40, 10, 'Shivakumar', 20, 92.7, 30}

# %%
#1.adding an element

# %%
st.add(50)

# %%
print(st)
# Out:
# {40, 10, 50, 'Shivakumar', 20, 92.7, 30}

# %%
#2.updating set

# %%
st.update([30,60,"letsupgrade"])

# %%
print(st)
# Out:
# {40, 10, 60, 50, 'Shivakumar', 20, 'letsupgrade', 92.7, 30}

# %%
#3.discard an element

# %%
st.discard(40)

# %%
print(st)
# Out:
# {10, 60, 50, 'Shivakumar', 20, 'letsupgrade', 92.7, 30}

# %%
#4.intersection of set

# %%
stA = { 3, 4, 5}

# %%
stB = {5, 6, 7}

# %%
stA.intersection(stB)
# Out:
# {5}

# %%
#5.symmetric difference

# %%
print(stA ^ stB)
# Out:
# {3, 4, 6, 7}

# %% [markdown]
# # tuple and its fucntions

# %%
tuple = ("shivakumar", 123, 50,)

# %%
#1.indexing

# %%
tuple
# Out:
# ('shivakumar', 123, 50)

# %%
print(tuple.index(50))
# Out:
# 2

# %%
#2.slicing

# %%
tuple = ("shivakumar", 123, 50, 3, 4, 5, 6)

# %%
print(tuple[1:3])
# Out:
# (123, 50)

# %%
#3 negative slicing

# %%
print(tuple[-4:-2])
# Out:
# (3, 4)

# %%
#4 reassigning tuple

# %%
tuple = ("a", "r", "b", [8, 9])

# %%
print(tuple)
# Out:
# ('a', 'r', 'b', [8, 9])

# %%
tuple[3][1] = 2

# %%
print(tuple)
# Out:
# ('a', 'r', 'b', [8, 2])

# %%
#5 membership test i tuple function

# %%
print("b" in tuple)
# Out:
# True

# %% [markdown]
# #Strings and its fun

# %%
str1 = "hello"

# %%
str2 = "welcome to letsupgrade"

# %%
str3 = "MAXIMUM"

# %%
#1 index

# %%
str1.index("e")
# Out:
# 1

# %%
#2 Swapcase

# %%
str2.format("e")
# Out:
# 'welcome to letsupgrade'

# %%
print(str2.swapcase())
# Out:
# WELCOME TO LETSUPGRADE

# %%
#3 lenth of the string

# %%
print(len(str2))
# Out:
# 22

# %%
#4 capitalization of string

# %%
print(str1.capitalize())
# Out:
# Hello

# %%
# 5 lowercase

# %%
print(str3.lower())
# Out:
# maximum
